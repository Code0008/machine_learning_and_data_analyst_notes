# %%
import seaborn as sns

# %% [markdown]
# relplot (Relational) : relacion estadistica entre variables de coonjuntos de datos
#      Scatter plot
#     -Lineplot
#     # las variables se interelacionan entre si

# %%
propinas = sns.load_dataset("tips")
propinas
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=propinas, 
            x="total_bill",
            y="tip")

# %%
sns.relplot(data=propinas, 
            x="total_bill",
            y="tip", 
            hue="smoker", style="smoker",
            size="size",
            col="time"
            #legend = None -> indicamos que no nos

           )

# %% [markdown]
# #

# %% [markdown]
# # Representacion distributiva (displot)
# cuantos casos tenemos en distintos grupos
# histplot
# kdeplot
# ecdfplot
# rugplot

# %%
pinguinos = sns.load_dataset("penguins")
pinguinos
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(
    data=pinguinos,
    x="body_mass_g",
    kde=True, # la linea continua de datos
    col="island"

)

# %%
help(sns.barplot)
# Out:
# Help on function barplot in module seaborn.categorical:
#
# barplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, estimator='mean', errorbar=('ci', 95), n_boot=1000, seed=None, units=None, weights=None, orient=None, color=None, palette=None, saturation=0.75, fill=True, hue_norm=None, width=0.8, dodge='auto', gap=0, log_scale=None, native_scale=False, formatter=None, legend='auto', capsize=0, err_kws=None, ci=<deprecated>, errcolor=<deprecated>, errwidth=<deprecated>, ax=None, **kwargs)
#     Show point estimates and errors as rectangular bars.
#
#     A bar plot represents an aggregate or statistical estimate for a numeric
#     variable with the height of each rectangle and indicates the uncertainty
#     around that estimate using an error bar. Bar plots include 0 in the
#     axis range, and they are a good choice when 0 is a meaningful value
#     for the variable to take.
#
#     See the :ref:`tutorial <categorical_tutorial>` for more information.
#
# ...

# %%
sns.displot(
    data=pinguinos,
    x="flipper_length_mm",
    kind="kde",
    rug=True # son las lineas que nos muestra la cantidad de casos individuales


)

# kde: estimacion de dencidad de kernel
#

# %%
sns.displot(
    data=pinguinos,
    x="flipper_length_mm",
    kind="ecdf"

)

# %% [markdown]
# # catplot ver graficos en categoria
#
#
# stipplot
# swarmplot
# boxplot
# violinplot
# poinplot
# barplot

# %%
sns.catplot(data=propinas, 
            kind="strip",
            x = "day", 
            y ="total_bill",
            hue="smoker"
            )

# veremos cuantas ventas haay de acuerdo al dia

# %%
sns.catplot(data=propinas, 
            kind="swarm",
            x = "day", 
            y ="total_bill",
            hue="smoker"
            )

#swarm esparce los puntos individualmente y proporciona la presentacion especifica

# %%
sns.catplot(data=propinas, 
            kind="box", 
            x = "day", 
            y ="total_bill",
            hue="smoker"
            )
# diagrama dec ajas y bigotes
# cajas representan los cuartiles medios del conjunto de datos 
# inferior el primer cuartil
# superior el tercer 75 porcioento
# liena que debide es es la mediana
#bigotes : datos en primer y ultimo cuartil 
# puntos valores atipicos en comparacion al conjunto de datos


# interpretacion:
    # dispercion, rango entre cuartiles que refrejan la disprecion de datos 
    # si la mediana no esta en el centro la caja indica que los datos esta sesgaods 
        # si es abajo hacia la derecha
        # arriba a la izquierda
        #

# %%
sns.catplot(data=propinas, 
            kind="violin", 
            x = "day", 
            y ="total_bill",
            hue="smoker"
            )

#el ancho representa la cantidad de repeticiones 
# frecunencias son las lineas del medio

# %%
sns.catplot(data=propinas, 
            kind="point", 
            x = "day", 
            y ="total_bill",
            hue="smoker"
            )

# %%
sns.catplot(
    data=propinas, 
    kind="bar", 
    x="day", 
    y="total_bill", 
    hue="smoker", 
    width=0.6,
    height=5,  # Altura del gráfico
    aspect=1.5  # Relación de aspecto
)





#el tamaño de la mbarra es la media de los valores de y de acuerdo a cada subgrupo que se le pase 
# en este caso subgrupo es de dia, fumador siono

# las barras de error qu ese muestran sobre los graficos simbolizan
# la vvarianca que hay entre los datos calculandoze entre un intervalo de confianza
# 
#  se suele representar la barra deacuerdo al tamaño de la muestra que le pasemos 
#  se calcula en base al error estandar de la media (SEM) 
# multiplicado por el valor critico asociado al nivel de confianza deseado 
    # valor critico  utilizando la destribucion normal estandar o distribucion t de student
    #  dependiendo del tamaño de la muestra y de si conocemos o no la desviación estándar de la población
    # distribucion normal estandar:
    #   Cuando tenemos una muestra grande (generalmente, n>30) o conocemos la desviación 
    # estándar de la población, utilizamos la distribución normal 
    # estándar para calcular el valor crítico. Este valor crítico
    #  corresponde a un punto en la curva de la distribución normal donde 
    # el área acumulada es igual al nivel de confianza deseado.
# y sumandose o restandose en relaxion a la media de ese grupo 
#

# %% [markdown]
# # multiples graficos en seaborn
# # join plot

# %%
pinguinos
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.jointplot(data= pinguinos,
              x= "flipper_length_mm",
              y= "bill_length_mm",
              hue="species")

#   grafico marginal,  nos ayudan ver como se agrupan la sdistintas despiec de acuerdo a las variables comparadas

# %%
sns.pairplot(data=pinguinos, 
             hue="species")

# toma todas las variables numericas del dataset y

# %%
#funciones nivel interior :V
#manejar a puño los datos 
grafico =  sns.PairGrid(data=pinguinos,
                         hue="species",
                        corner=True, # no veremos graficos repetidos osea  que se inversan entre eje x y y
                        )

# %%
#funciones nivel interior :V
#manejar a puño los datos 
grafico =  sns.PairGrid(data=pinguinos,
                         hue="species",
                        corner=True, # no veremos graficos repetidos osea  que se inversan entre eje x y y
                        )

grafico.map_lower(sns.kdeplot, # usamos el grafico kde
                   hue=None, 
                   level=5,
                     color=".2")
# Out:
# C:\Users\gama\AppData\Roaming\Python\Python312\site-packages\seaborn\distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\gama\AppData\Roaming\Python\Python312\site-packages\seaborn\distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\gama\AppData\Roaming\Python\Python312\site-packages\seaborn\distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\gama\AppData\Roaming\Python\Python312\site-packages\seaborn\distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\gama\AppData\Roaming\Python\Python312\site-packages\seaborn\distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# ...

# %%
help(sns.heatmap)
# Out:
# Help on function heatmap in module seaborn.matrix:
#
# heatmap(
#     data,
#     *,
#     vmin=None,
#     vmax=None,
#     cmap=None,
#     center=None,
#     robust=False,
#     annot=None,
#     fmt='.2g',
#     annot_kws=None,
#     linewidths=0,
#     linecolor='white',
#     cbar=True,
#     cbar_kws=None,
#     cbar_ax=None,
#     square=False,
#     xticklabels='auto',
#     yticklabels='auto',
#     mask=None,
#     ax=None,
#     **kwargs
# )
#     Plot rectangular data as a color-encoded matrix.
#
#     This is an Axes-level function and will draw the heatmap into the
#     currently-active Axes if none is provided to the ``ax`` argument.  Part of
#     this Axes space will be taken and used to plot a colormap, unless ``cbar``
#     is False or a separate Axes is provided to ``cbar_ax``.
#
#     Parameters
#     ----------
#     data : rectangular dataset
#         2D dataset that can be coerced into an ndarray. If a Pandas DataFrame
# ...

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

class Venta:
    def __init__(self, datos):
        """
        Inicializa la clase Venta con un DataFrame de datos.
        """
        self.datos = pd.DataFrame(datos)
    
    def agregar_fecha_vencimiento(self, fechas_vencimiento):
        """
        Agrega una columna de fecha de vencimiento en el formato dd/mm/AAAA.
        """
        self.datos['fecha_vencimiento'] = fechas_vencimiento
    
    def calcular_media_ponderada(self, columna_precio, columna_cantidad):
        """
        Calcula la media ponderada del precio de venta.
        """
        self.datos['media_ponderada'] = (self.datos[columna_precio] * self.datos[columna_cantidad]).sum() / self.datos[columna_cantidad].sum()
    
    def calcular_estadisticas(self, columna):
        """
        Calcula la mediana, moda, varianza y desviación estándar de una columna específica.
        """
        mediana = self.datos[columna].median()
        moda = self.datos[columna].mode()[0]
        varianza = self.datos[columna].var()
        desviacion = self.datos[columna].std()
        return mediana, moda, varianza, desviacion
    
    def agregar_columna_vencido(self):
        """
        Agrega una columna indicando si el producto está vencido o no.
        """
        hoy = datetime.now()
        self.datos['vencido'] = self.datos['fecha_vencimiento'].apply(lambda x: 'Sí' if datetime.strptime(x, '%d/%m/%Y') < hoy else 'No')
    
    def calcular_rotacion_inventario(self):
        """
        Calcula la rotación de inventario para productos no vencidos.
        """
        self.datos['rotacion'] = (self.datos['precio_venta'] - self.datos['precio_compra']) / self.datos['stock_promedio']
    
    def ordenar_datos(self):
        """
        Ordena el DataFrame por ganancias de productos no vencidos y por categoría y stock.
        """
        self.datos = self.datos[self.datos['vencido'] == 'No']
        self.datos = self.datos.sort_values(by=['ganancia', 'stock', 'categoria'], ascending=[False, True, True])
    
    def mostrar_grafico_ventas_por_ubicacion(self):
        """
        Genera un gráfico de las ventas totales por ubicación y producto.
        """
        ventas_por_ubicacion = self.datos.groupby(['ubicacion', 'nombre_producto'])['precio_venta'].sum().unstack()
        ventas_por_ubicacion.plot(kind='bar', stacked=True, figsize=(10, 7))
        plt.title('Ventas Totales por Ubicación y Producto')
        plt.xlabel('Ubicación')
        plt.ylabel('Ventas Totales')
        plt.show()
    
    def mostrar_grafico_distribucion_ventas(self):
        """
        Genera un gráfico de la distribución de ventas por ubicación.
        """
        sns.histplot(data=self.datos, x='ubicacion', weights='precio_venta', kde=True)
        plt.title('Distribución de Ventas por Ubicación')
        plt.xlabel('Ubicación')
        plt.ylabel('Ventas')
        plt.show()
