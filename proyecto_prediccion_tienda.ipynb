# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import MinMaxScaler

# %%
dataset = pd.read_csv("Ventas.csv")
dataset
# Out:
#           Fecha  DíaDeLaSemana  Promociones  Festivo  Ventas
# 0    2022-01-01              6            0        0    4033
# 1    2022-01-02              7            0        1    4012
# 2    2022-01-03              1            0        0    1608
# 3    2022-01-04              2            1        0    2046
# 4    2022-01-05              3            0        0    2484
# ..          ...            ...          ...      ...     ...
# 360  2022-12-27              2            1        0    2189
# 361  2022-12-28              3            0        0    2548
# 362  2022-12-29              4            0        0    3018
# 363  2022-12-30              5            0        0    3591
# 364  2022-12-31              6            1        0    4351
#
# [365 rows x 5 columns]

# %%
normalizador = MinMaxScaler(feature_range=(0,1))
nuevo_dataframe = normalizador.fit_transform(dataset.iloc[:,1:-1])
nuevo_dataframe =  pd.DataFrame(data=nuevo_dataframe, columns=dataset.columns[1:-1])
nuevo_dataframe
# Out:
#      DíaDeLaSemana  Promociones  Festivo
# 0         0.833333          0.0      0.0
# 1         1.000000          0.0      1.0
# 2         0.000000          0.0      0.0
# 3         0.166667          1.0      0.0
# 4         0.333333          0.0      0.0
# ..             ...          ...      ...
# 360       0.166667          1.0      0.0
# 361       0.333333          0.0      0.0
# 362       0.500000          0.0      0.0
# 363       0.666667          0.0      0.0
# 364       0.833333          1.0      0.0
#
# [365 rows x 3 columns]

# %%
X= nuevo_dataframe
Y = dataset["Ventas"]

X_entrenamiento, X_prueba, y_entrenamiento, y_prueba = train_test_split(X,Y, train_size=0.7, random_state=1)

# %%
modelos = {
    "reg_log": LinearRegression(),
    "tree": DecisionTreeRegressor(),
    "bosque": RandomForestRegressor()
}
estadisticas = [

]
for nombre,modelo in modelos.items():
    modelo.fit(X_entrenamiento,y_entrenamiento)
    prediccion = modelo.score(X_prueba, y_prueba)
    print(f"Prediccion es de: {prediccion*100}")
# Out:
# Prediccion es de: 98.61802821029751
# Prediccion es de: 98.60768674324035
# Prediccion es de: 98.60306959631339

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
df = pd.read_csv("tarjetas_credito.csv")

escala = MinMaxScaler(feature_range=(0,1))
normado = escala.fit_transform(df)
df =pd.DataFrame(normado, columns=df.columns)
df.head()
X = df.iloc[:, :-1]
y = df.iloc[: ,-1]
X_entrenamiento, X_prueba, y_entrenamiento, y_prueba = train_test_split(X, y, train_size=0.7, random_state=1)
aleatorio_bosque = RandomForestClassifier()

aleatorio_bosque.fit(X_entrenamiento, y_entrenamiento)
aleatorio_bosque.score(X_prueba, y_prueba)
nuevo_registro = pd.DataFrame({
    'Duracion': [0.000006], 'V1': [0.452345], 'V2': [0.564789], 'V3': [0.123456], 'V4': [0.654321],
    'V5': [0.987654], 'V6': [0.345678], 'V7': [0.234567], 'V8': [0.876543], 'V9': [0.456789],
    'V10': [0.567890], 'V11': [0.678901], 'V12': [0.789012], 'V13': [0.890123], 'V14': [0.901234],
    'V15': [0.012345], 'V16': [0.543210], 'V17': [0.432109], 'V18': [0.321098], 'V19': [0.210987],
    'V20': [0.109876], 'V21': [0.098765], 'V22': [0.887654], 'V23': [0.776543], 'V24': [0.665432],
    'V25': [0.554321],     'V26': [0.443210], 'V27': [0.332109], 'V28': [0.221098], 'Monto': [0.110987]
}, index=[0])

prediccion = aleatorio_bosque.predict(nuevo_registro)
prediccion
probabilidades_legitimidad = aleatorio_bosque.predict_proba(nuevo_registro) 
probabilidades_legitimidad
